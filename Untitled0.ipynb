# %% [markdown]
# <a href="https://colab.research.google.com/github/EternalStudy/Collab/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
"Найдите, какая область центрального федерального округа имела наибольшую численность студентов вечерней формы обучения в 2015 году."
df = pd.read_csv('/content/data20152019.csv', sep= ';', encoding='cp1251')
df
# Out:
#                          Субъект РФ  \
# 0              Российская Федерация
# 1     Центральный федеральный округ
# 2              Белгородская область
# 3                  Брянская область
# 4              Владимирская область
# ..                              ...
# 89                 Амурская область
# 90              Магаданская область
# 91              Сахалинская область
# 92     Еврейская автономная область
# 93       Чукотский автономный округ
#
#     Численность студентов, всего человек, 2015  \
# 0                                      4766479
# 1                                      1455273
# 2                                        53050
# 3                                        34540
# 4                                        33461
# ..                                         ...
# 89                                       19361
# 90                                        4451
# 91                                        8889
# ...

# %%
df= pd.DataFrame(df,columns = ['Субъект РФ','Численность студентов очно-заочная (вечерняя) форма, человек, 2015'])
df
# Out:
#                          Субъект РФ  \
# 0              Российская Федерация
# 2              Белгородская область
# 3                  Брянская область
# 4              Владимирская область
# 5               Воронежская область
# ..                              ...
# 88                 Хабаровский край
# 89                 Амурская область
# 90              Магаданская область
# 91              Сахалинская область
# 92     Еврейская автономная область
#
#     Численность студентов очно-заочная (вечерняя) форма, человек, 2015
# 0                                              149102
# 2                                                 290
# 3                                                 624
# 4                                                 217
# 5                                                2124
# ..                                                ...
# 88                                                584
# 89                                                270
# ...

# %%
msk = df['Субъект РФ'].str.contains('округ')
df = df.drop(df[msk].index)
df
# Out:
#                          Субъект РФ  \
# 0              Российская Федерация
# 2              Белгородская область
# 3                  Брянская область
# 4              Владимирская область
# 5               Воронежская область
# ..                              ...
# 88                 Хабаровский край
# 89                 Амурская область
# 90              Магаданская область
# 91              Сахалинская область
# 92     Еврейская автономная область
#
#     Численность студентов очно-заочная (вечерняя) форма, человек, 2015
# 0                                              149102
# 2                                                 290
# 3                                                 624
# 4                                                 217
# 5                                                2124
# ..                                                ...
# 88                                                584
# 89                                                270
# ...

# %%
msk = df['Субъект РФ'].str.contains('Российская Федерация')
df = df.drop(df[msk].index)
df
# Out:
#                          Субъект РФ  \
# 2              Белгородская область
# 3                  Брянская область
# 4              Владимирская область
# 5               Воронежская область
# 6                Ивановская область
# ..                              ...
# 88                 Хабаровский край
# 89                 Амурская область
# 90              Магаданская область
# 91              Сахалинская область
# 92     Еврейская автономная область
#
#     Численность студентов очно-заочная (вечерняя) форма, человек, 2015
# 2                                                 290
# 3                                                 624
# 4                                                 217
# 5                                                2124
# 6                                                 188
# ..                                                ...
# 88                                                584
# 89                                                270
# ...

# %%
msk = df['Субъект РФ'].str.contains('г.')
df = df.drop(df[msk].index)
df
# Out:
#                          Субъект РФ  \
# 3                  Брянская область
# 4              Владимирская область
# 5               Воронежская область
# 6                Ивановская область
# 7                 Калужская область
# ..                              ...
# 87                  Приморский край
# 88                 Хабаровский край
# 89                 Амурская область
# 91              Сахалинская область
# 92     Еврейская автономная область
#
#     Численность студентов очно-заочная (вечерняя) форма, человек, 2015
# 3                                                 624
# 4                                                 217
# 5                                                2124
# 6                                                 188
# 7                                                 303
# ..                                                ...
# 87                                               1173
# 88                                                584
# ...

# %%
max_value = df['Численность студентов очно-заочная (вечерняя) форма, человек, 2015'].max()
df[df['Численность студентов очно-заочная (вечерняя) форма, человек, 2015'] == max_value]
# Out:
#               Субъект РФ  \
# 61     Самарская область
#
#     Численность студентов очно-заочная (вечерняя) форма, человек, 2015
# 61                                               4726
